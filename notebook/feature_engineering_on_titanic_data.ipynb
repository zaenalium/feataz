# %%
import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
from feataz.encoders import *

# %%
OneHotEncoder
# Out:
# feataz.encoders.OneHotEncoder

# %%
OneHotEncoder(["Pclass"], drop_first = True).fit_transform(df)
# Out:
# shape: (891, 13)
# ┌─────────────┬──────────┬─────────────────┬────────┬───┬───────┬──────────┬───────────┬───────────┐
# │ PassengerId ┆ Survived ┆ Name            ┆ Sex    ┆ … ┆ Cabin ┆ Embarked ┆ Pclass__2 ┆ Pclass__3 │
# │ ---         ┆ ---      ┆ ---             ┆ ---    ┆   ┆ ---   ┆ ---      ┆ ---       ┆ ---       │
# │ i64         ┆ i64      ┆ str             ┆ str    ┆   ┆ str   ┆ str      ┆ i8        ┆ i8        │
# ╞═════════════╪══════════╪═════════════════╪════════╪═══╪═══════╪══════════╪═══════════╪═══════════╡
# │ 1           ┆ 0        ┆ Braund, Mr.     ┆ male   ┆ … ┆ null  ┆ S        ┆ 0         ┆ 1         │
# │             ┆          ┆ Owen Harris     ┆        ┆   ┆       ┆          ┆           ┆           │
# │ 2           ┆ 1        ┆ Cumings, Mrs.   ┆ female ┆ … ┆ C85   ┆ C        ┆ 0         ┆ 0         │
# │             ┆          ┆ John Bradley    ┆        ┆   ┆       ┆          ┆           ┆           │
# ...

# %%
OrdinalEncoder(["Name"], drop_original=False).fit_transform(df)
# Out:
# shape: (891, 13)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬─────────┬───────┬──────────┬───────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Fare    ┆ Cabin ┆ Embarked ┆ Name__ord │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---     ┆ ---   ┆ ---      ┆ ---       │
# │ i64         ┆ i64      ┆ i64    ┆ str               ┆   ┆ f64     ┆ str   ┆ str      ┆ i64       │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═════════╪═══════╪══════════╪═══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ 7.25    ┆ null  ┆ S        ┆ 108       │
# │             ┆          ┆        ┆ Harris            ┆   ┆         ┆       ┆          ┆           │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ 71.2833 ┆ C85   ┆ C        ┆ 190       │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆         ┆       ┆          ┆           │
# ...

# %%
df = pl.DataFrame({
        "cat": ["a", "b", "a", "c", "b", "a"],
        "x": [1.0, 2.5, 0.5, 3.2, 2.7, 4.1],
        "y": [0, 1, 0, 1, 1, 0],
    })

# %%
df3 = CountFrequencyEncoder(["cat"], normalize=True).fit_transform(df)

# %%
df3
# Out:
# shape: (6, 3)
# ┌─────┬─────┬────────────┐
# │ x   ┆ y   ┆ cat__count │
# │ --- ┆ --- ┆ ---        │
# │ f64 ┆ i64 ┆ f64        │
# ╞═════╪═════╪════════════╡
# │ 1.0 ┆ 0   ┆ 0.5        │
# │ 2.5 ┆ 1   ┆ 0.333333   │
# │ 0.5 ┆ 0   ┆ 0.5        │
# │ 3.2 ┆ 1   ┆ 0.166667   │
# │ 2.7 ┆ 1   ┆ 0.333333   │
# │ 4.1 ┆ 0   ┆ 0.5        │
# └─────┴─────┴────────────┘
